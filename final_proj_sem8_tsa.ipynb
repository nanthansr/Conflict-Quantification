# %%
import datetime
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os

from datetime import datetime

# %%
df = pd.read_csv("/content/drive/MyDrive/mod_df.csv")
# Out:
# <ipython-input-50-ae35690a0fab>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/mod_df.csv")

# %%
for index, row in df.iterrows():
  df['avg'] = (df['likes'] + df['retweets'] + df['comments'])/3

# %%
df.head(10)
# Out:
#   Unnamed: 0                                 User  \
# 0          0  https://twitter.com/covid19_info_jp
# 1          1   https://twitter.com/Krishna_000000
# 2          2  https://twitter.com/covid19_info_jp
# 3          3  https://twitter.com/covid19_info_jp
# 4          4  https://twitter.com/JinVDefinatelyU
# 5          5  https://twitter.com/covid19_info_jp
# 6          6         https://twitter.com/mommaesq
# 7          7         https://twitter.com/mommaesq
# 8          8  https://twitter.com/covid19_info_jp
# 9          9  https://twitter.com/covid19_info_jp
#
#                               hash  \
# 0  ['æ°åã³ã­ã', 'Covid_19']
# 1                              NaN
# 2  ['æ°åã³ã­ã', 'Covid_19']
# 3  ['æ°åã³ã­ã', 'Covid_19']
# 4                              NaN
# 5  ['æ°åã³ã­ã', 'Covid_19']
# 6                              NaN
# 7            ['opencalifornianow']
# 8  ['æ°åã³ã­ã', 'Covid_19']
# 9  ['æ°åã³ã­ã', 'Covid_19']
#
# ...

# %%
df['sno'].max()
# Out:
# 3485

# %%
grouped = df.groupby('sno')
grouped

# %%
grouped.head(10)
# Out:
#        Unnamed: 0                                 User  \
# 0               0  https://twitter.com/covid19_info_jp
# 1               1   https://twitter.com/Krishna_000000
# 2               2  https://twitter.com/covid19_info_jp
# 3               3  https://twitter.com/covid19_info_jp
# 4               4  https://twitter.com/JinVDefinatelyU
# ...           ...                                  ...
# 170004          8     https://twitter.com/OfficialAj_3
# 170005          9    https://twitter.com/Indian_Bhakts
# 170017          0   https://twitter.com/MorganEscherly
# 170018          1    https://twitter.com/2141Gmatthews
# 170019          2     https://twitter.com/Eddie_000000
#
#                                    hash  \
# 0       ['æ°åã³ã­ã', 'Covid_19']
# 1                                   NaN
# 2       ['æ°åã³ã­ã', 'Covid_19']
# 3       ['æ°åã³ã­ã', 'Covid_19']
# 4                                   NaN
# ...                                 ...
# ...

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize = (8, 8))
ax.set_xlabel('date')
ax.set_ylabel('month')
ax.set_title('Lifetime of the conflict')

# Loop through each group and plot the line
for date, group in grouped:
    ax.plot(group['Date'], group['month'], label=date)

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize = (8, 8))
ax.set_title('Lifetime of a conflict based on year')

ax.set_xlabel('month')
ax.set_ylabel('year')
# Loop through each group and plot the line
for date, group in grouped:
    ax.plot(group['month'], group['year'], label=date)

# %%
df_grouped
# Out:
#              likes  comments  retweets
# date
# 01-02-2021    74.0      13.0       4.0
# 01-03-2021    62.0      25.0      28.0
# 01-04-2020   874.0      37.0     123.0
# 01-04-2021  1468.0     168.0     232.0
# 01-05-2020   663.0     291.0     191.0
# ...            ...       ...       ...
# 31-03-2021  1580.0      59.0     249.0
# 31-05-2020   611.0      54.0     102.0
# 31-07-2020    30.0      29.0       1.0
# 31-08-2020    50.0      38.0       5.0
# 31-10-2020    77.0      18.0      14.0
#
# [366 rows x 3 columns]

# %%
df_grouped = df.groupby('date')[['likes', 'comments', 'retweets']].sum()

# Plot the data as separate lines for each metric
ax = df_grouped.plot(kind='line', figsize=(8, 6), grid=True)

# Set the title and axis labels
ax.set_title('Interactions Over Time', fontsize=16)
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Number of Interactions', fontsize=12)

# Show the plot
plt.show()

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize = (8, 8))
ax.set_title('Total interactions of tweets vs year')

ax.set_xlabel('year')
ax.set_ylabel('total interactions')
# Loop through each group and plot the line
for date, group in grouped:
    ax.plot(group['year'], group['sum'], label=date)

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize = (8, 8))
ax.set_title('Likes of tweets vs year')

ax.set_xlabel('year')
ax.set_ylabel('likes')
# Loop through each group and plot the line
for date, group in grouped:
    ax.plot(group['year'], group['likes'], label=date)

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize = (8, 8))
ax.set_title('retweets vs year')

ax.set_xlabel('year')
ax.set_ylabel('retweets')
# Loop through each group and plot the line
for date, group in grouped:
    ax.plot(group['year'], group['retweets'], label=date)

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize = (8, 8))
ax.set_title('comments vs year')

ax.set_xlabel('year')
ax.set_ylabel('comments')
# Loop through each group and plot the line
for date, group in grouped:
    ax.plot(group['year'], group['comments'], label=date)

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize = (8, 8))
ax.set_xlabel('date')
ax.set_ylabel('Total interactions')
ax.set_title('Peak interactions of Tweets')

# Loop through each group and plot the line
for date, group in grouped:
    ax.plot(group['date'], group['sum'], label=date)
    ax.set_ylim([0, 2000])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-360c0c63d9af> in <cell line: 8>()
#       7 # Loop through each group and plot the line
#       8 for date, group in grouped:
# ----> 9     ax.plot(group['date'], group['sum'], label=date)
#      10     ax.set_ylim([0, 2000])
#      11
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# ...

# %%
df.to_csv('/content/drive/MyDrive/mod_df.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-21df35e4ba4d> in <cell line: 1>()
# ----> 1 df.to_csv('/content/drive/MyDrive/mod_df.csv', index=False)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718         )
#    3719
# -> 3720         return DataFrameRenderer(formatter).to_csv(
# ...

# %%
dd = df

# %%
dd = dd.sort_values(by='sum', ascending=False)

# %%
dk = dd.sort_values(by='sno', ascending=False)

# %%
dd.head(10)
# Out:
#       Unnamed: 0                              User  \
# 70125        138   https://twitter.com/mayursejpal
# 71739          8   https://twitter.com/mayursejpal
# 26207         14  https://twitter.com/updatecharts
# 40413          8    https://twitter.com/wongjiyuet
# 40225         13    https://twitter.com/wongjiyuet
# 43053          2    https://twitter.com/wongjiyuet
# 41448          5    https://twitter.com/wongjiyuet
# 43039          1    https://twitter.com/wongjiyuet
# 42990          1    https://twitter.com/wongjiyuet
# 40425         10    https://twitter.com/wongjiyuet
#
#                                                     hash  \
# 70125                                                NaN
# 71739                                                NaN
# 26207                                    ['BANGBANGCON']
# 40413  ['721äºä»¶ä¸é±å¹´', '721YeungLongTerroristA...
# 40225  ['721äºä»¶ä¸é±å¹´', '721YeungLongTerroristA...
# ...

# %%
dd.shape
# Out:
# (79012, 14)

# %%
d1 = dd
unq = d1.drop_duplicates(subset=['sum'], keep=False)

# %%
unq.head(10)
# Out:
#       Unnamed: 0                              User  \
# 26207         14  https://twitter.com/updatecharts
# 46487        117   https://twitter.com/NSFVoyager2
# 78567          5      https://twitter.com/LaysaIS2
# 5090         132   https://twitter.com/NSFVoyager2
# 62108        408   https://twitter.com/NSFVoyager2
# 61993        293   https://twitter.com/NSFVoyager2
# 36124        474   https://twitter.com/NSFVoyager2
# 55710          3   https://twitter.com/gulf_gfd_cn
# 35995        345   https://twitter.com/NSFVoyager2
# 59093        342   https://twitter.com/NSFVoyager2
#
#                                                     hash  \
# 26207                                    ['BANGBANGCON']
# 46487                                                NaN
# 78567                                                NaN
# 5090                                                 NaN
# 62108                                                NaN
# ...

# %%
unq['sno']
# Out:
# 26207     836
# 46487    1806
# 78567    3468
# 5090      210
# 62108    2625
#          ...
# 49109    1917
# 25175     805
# 39117    1323
# 4791      202
# 62494    2657
# Name: sno, Length: 101, dtype: int64

# %%
df["sno"]
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#          ...
# 79007    3485
# 79008    3485
# 79009    3485
# 79010    3485
# 79011    3485
# Name: sno, Length: 79012, dtype: int64

# %%
df.head()
# Out:
#   Unnamed: 0                                 User  \
# 0          0  https://twitter.com/covid19_info_jp
# 1          1   https://twitter.com/Krishna_000000
# 2          2  https://twitter.com/covid19_info_jp
# 3          3  https://twitter.com/covid19_info_jp
# 4          4  https://twitter.com/JinVDefinatelyU
#
#                               hash  \
# 0  ['æ°åã³ã­ã', 'Covid_19']
# 1                              NaN
# 2  ['æ°åã³ã­ã', 'Covid_19']
# 3  ['æ°åã³ã­ã', 'Covid_19']
# 4                              NaN
#
#                                              content  likes  retweets  \
# 0  æ°åã³ã­ãã¦ã¤ã«ã¹å½å
# ææã®ç¶æ...    1.0       0.0
# 1  @bigbasket_com \nMade the mistake of ordering ...    0.0       0.0
# 2  æ°åã³ã­ãã¦ã¤ã«ã¹å½å
# ææã®ç¶æ...    0.0       0.0
# 3  æ°åã³ã­ãã¦ã¤ã«ã¹å½å
# ææã®ç¶æ...    0.0       0.0
# 4  @Zigmanfreud What about that little rally? You...    0.0       0.0
#
# ...

# %%
conflict_df = dd[dd['sno'] == 3054]
conflict_df = conflict_df.sort_values(by='month', ascending=True)

conflict_df.set_index('date', inplace=True)

conflict_df[['likes', 'retweets', 'comments']].sum(axis=1).plot(kind='line')

# set plot title and axis labels
plt.title('Sum of Likes, Retweets, and Comments over Time')
plt.xlabel('Date')
plt.ylabel('Total Count')

# display the plot
plt.show()

# %%
new_df = conflict_df[['month','year','likes','comments','retweets','sum']]

# %%
new_df = new_df.sort_values(by='month', ascending=True)
new_df.head()
# Out:
#             month    year   likes  comments  retweets     sum
# date
# 31-03-2021    3.0  2021.0     4.0       2.0       0.0     6.0
# 28-03-2021    3.0  2021.0  5052.0      88.0    1614.0  6754.0
# 28-03-2021    3.0  2021.0     2.0       1.0       0.0     3.0
# 28-03-2021    3.0  2021.0     4.0       0.0       0.0     4.0
# 27-03-2021    3.0  2021.0     0.0       0.0       0.0     0.0

# %%
conflict_df1 = dd[dd['sno'] == 836]
conflict_df1 = conflict_df1.sort_values(by='month', ascending=True)

conflict_df1.set_index('date', inplace=True)

conflict_df1[['likes', 'retweets', 'comments']].sum(axis=1).plot(kind='line')

# set plot title and axis labels
plt.title('Sum of Likes, Retweets, and Comments over Time')
plt.xlabel('Date')
plt.ylabel('Total Count')

# display the plot
plt.show()

# %%
conflict_df1.shape
# Out:
# (22, 13)

# %%
new_df1 = conflict_df1[['month','year','likes','comments','retweets','sum']]
new_df1 = new_df1.sort_values(by='month', ascending=True)
new_df1.head()
# Out:
#             month    year  likes  comments  retweets  sum
# date
# 31-03-2020    3.0  2020.0    0.0       1.0       0.0  1.0
# 30-03-2020    3.0  2020.0    0.0       0.0       0.0  0.0
# 09-04-2020    4.0  2020.0    1.0       1.0       0.0  2.0
# 02-04-2020    4.0  2020.0    2.0       0.0       0.0  2.0
# 23-04-2020    4.0  2020.0    1.0       0.0       0.0  1.0

# %%
c_df1 = new_df1[['likes','comments','retweets']]
c_df1 = c_df1.sort_values(by='date')

# %%
ax = c_df1.plot(kind='line', figsize=(10, 8), grid=True)
ax.set_title('Interactions over Time for Top 2nd conflict')
# Out:
# Text(0.5, 1.0, 'Interactions over Time for Top 2nd conflict')

# %%
c_df = new_df[['likes','comments','retweets','sum']]

# %%
c_df = c_df.sort_values(by='date')

# %%
ax = c_df.plot(kind='line', figsize=(10, 8), grid=True)
ax.set_title('Interactions over Time for Top 1 conflict')
# Out:
# Text(0.5, 1.0, 'Interactions over Time for Top 1 conflict')

# %%
ax = new_df.plot(kind='line', figsize=(8, 6), grid=True)

# %%
conflict_df['Dates'] = pd.to_datetime(conflict_df['Dates'], format='%d%m%y')

# %%
conflict_df
# Out:
#            Unnamed: 0                                 User  \
# date
# 28-03-2021        138      https://twitter.com/mayursejpal
# 24-03-2021        160         https://twitter.com/sade_iam
# 24-03-2021        158   https://twitter.com/Krishna_000000
# 27-03-2021        141    https://twitter.com/Admire_kjohar
# 26-03-2021        152         https://twitter.com/vusjibin
# ...               ...                                  ...
# 05-04-2021         73      https://twitter.com/danwalmsley
# 02-04-2021         86           https://twitter.com/uzitup
# 05-04-2021         69      https://twitter.com/RoseHemIock
# 07-04-2021         48  https://twitter.com/umbrella_000000
# 16-04-2021         16       https://twitter.com/PetrifiedW
#
#                                         hash  \
# date
# 28-03-2021                               NaN
# 24-03-2021                               NaN
# 24-03-2021                               NaN
# 27-03-2021                               NaN
# ...

# %%
cf_df = conflict_df.groupby('date')[['likes', 'comments', 'retweets']].sum()
cf_df = cf_df.sort_values(by='date', ascending=True)
ax = cf_df.plot(kind='line', figsize=(8, 6), grid=True)

# %%
conflict_df.head()
# Out:
#            Unnamed: 0                                 User  \
# date
# 01-04-2021        106  https://twitter.com/umbrella_000000
# 01-04-2021         99  https://twitter.com/umbrella_000000
# 01-04-2021         98  https://twitter.com/umbrella_000000
# 01-04-2021         95  https://twitter.com/umbrella_000000
# 01-04-2021         96  https://twitter.com/umbrella_000000
#
#                                         hash  \
# date
# 01-04-2021  ['SixTONES', 'FridayLivestream']
# 01-04-2021  ['SixTONES', 'FridayLivestream']
# 01-04-2021  ['SixTONES', 'FridayLivestream']
# 01-04-2021  ['SixTONES', 'FridayLivestream']
# 01-04-2021  ['SixTONES', 'FridayLivestream']
#
#                                                       content  likes  \
# date
# 01-04-2021  REQUEST #SixTONES @MTV #FridayLivestream\n\nSi...    0.0
# 01-04-2021  REQUEST #SixTONES @MTV #FridayLivestream\n\nð...    0.0
# 01-04-2021  REQUEST #SixTONES @MTV #FridayLivestream\n\nå...    0.0
# ...

# %%
cf_df.head()
# Out:
# 3.0

# %%
conflict_df.head()
# Out:
#            Unnamed: 0                                User hash  \
# date
# 28-03-2021        138     https://twitter.com/mayursejpal  NaN
# 24-03-2021        160        https://twitter.com/sade_iam  NaN
# 24-03-2021        158  https://twitter.com/Krishna_000000  NaN
# 27-03-2021        141   https://twitter.com/Admire_kjohar  NaN
# 26-03-2021        152        https://twitter.com/vusjibin  NaN
#
#                                                       content   likes  \
# date
# 28-03-2021  Tirupati Balaji temple fed 70000+ people on da...  5052.0
# 24-03-2021  @TopeTops Idiots they asked for card details a...     0.0
# 24-03-2021  @DefenderOfInd @7ru7h_1 @ChinarcorpsIA Helping...     0.0
# 27-03-2021  @Sassy_Pharm @Krishna_000000 You have a right ...     1.0
# 26-03-2021  @000000_flag @Correct52045242 @ReeferMadnesNC ...     0.0
#
#             retweets  comments   sno  Date  month    year     sum          avg
# date
# ...

# %%
cf = conflict_df.sort_values(by='sum', ascending=False)

# %%
cf.head()
# Out:
#            Unnamed: 0                                User hash  \
# date
# 28-03-2021        138     https://twitter.com/mayursejpal  NaN
# 03-04-2021         79   https://twitter.com/lillie_000000  NaN
# 17-04-2021         14   https://twitter.com/MandyTiffany1  NaN
# 18-04-2021          8       https://twitter.com/hexhamguy  NaN
# 12-04-2021         28  https://twitter.com/Krishna_000000  NaN
#
#                                                       content   likes  \
# date
# 28-03-2021  Tirupati Balaji temple fed 70000+ people on da...  5052.0
# 03-04-2021  @nprscottsimon @NegarMortazavi She has repeate...    45.0
# 17-04-2021  @sophielouisecc @kt_000000 Yes it would. The U...    28.0
# 18-04-2021  @Mikey1732 @kt_000000 Sincerely hope the torie...    23.0
# 12-04-2021  @business Such talk benefits only rich people....    32.0
#
#             retweets  comments   sno  Date  month    year     sum          avg
# date
# ...

# %%
top1 = df[df['sno'] == 8294]

# %%
top1.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, User, hash, content, likes, retweets, comments, sno, date, Date, month, year, sum, avg]
# Index: []

# %%
top1['sum'].max()
# Out:
# nan

# %%
top1_sort = top1.sort_values(by='date', ascending=True)

# %%
top1_sort.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, User, hash, content, likes, retweets, comments, sno, date, Date, month, year, sum, avg]
# Index: []

# %%
for sno in top1['sno'] :
  plt.plot(top1['date'], top1["likes"])
  plt.plot(top1['date'], top1["retweets"])
  plt.plot(top1['date'], top1["comments"])

plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for sno in top1['sno'] :
  plt.plot(top1['date'], top1["sum"],linewidth=2)


plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
top2 = df[df['sno'] == 7889]
top2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, User, hash, content, likes, retweets, comments, sno, date, Date, month, year, sum, avg]
# Index: []

# %%
top2['sum'].max()
# Out:
# 8347.0

# %%
for sno in top2['sno'] :
  plt.plot(top2['date'], top2["sum"],linewidth=2)


plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize = (8, 8))
ax.set_xlabel('date')
ax.set_ylabel('Total interactions')
ax.set_title('Peak interactions of Tweets')

# Loop through each group and plot the line
# for date, group in grouped:
#   if grouped['sno'] == 8294 :
#     ax.plot(group['date'], group['sum'], label=date)
#     ax.set_ylim([0, 2000])

for sno in df['sno'] :
  if sno == 8924 :
    ax.plot(df['date'], df['sum'], label=date)

# %%
unq.head(10)
# Out:
#        Unnamed: 0                                 User  \
# 169004         88  https://twitter.com/Shion_hoshikuzu
# 159167          7  https://twitter.com/honmono_ibrahim
# 26207          14     https://twitter.com/updatecharts
# 85984          35        https://twitter.com/girbagely
# 169136        220      https://twitter.com/NSFVoyager2
# 88797          13   https://twitter.com/thakkar_sameet
# 149115        485      https://twitter.com/NSFVoyager2
# 106921        161      https://twitter.com/NSFVoyager2
# 153773        256      https://twitter.com/NSFVoyager2
# 86107         158    https://twitter.com/taIkingmartin
#
#                                                hash  \
# 169004  ['VioletAtelier', 'UkiVioleta', 'UkiThumb']
# 159167                                          NaN
# 26207                               ['BANGBANGCON']
# 85984                                           NaN
# 169136                                          NaN
# ...

# %%
unq = unq.sort_values(by='sum', ascending=False)

# %%
un = unq.head(10)

# %%
un.head(10)
# Out:
#        Unnamed: 0                                 User  \
# 169004         88  https://twitter.com/Shion_hoshikuzu
# 159167          7  https://twitter.com/honmono_ibrahim
# 26207          14     https://twitter.com/updatecharts
# 85984          35        https://twitter.com/girbagely
# 169136        220      https://twitter.com/NSFVoyager2
# 88797          13   https://twitter.com/thakkar_sameet
# 149115        485      https://twitter.com/NSFVoyager2
# 106921        161      https://twitter.com/NSFVoyager2
# 153773        256      https://twitter.com/NSFVoyager2
# 86107         158    https://twitter.com/taIkingmartin
#
#                                                hash  \
# 169004  ['VioletAtelier', 'UkiVioleta', 'UkiThumb']
# 159167                                          NaN
# 26207                               ['BANGBANGCON']
# 85984                                           NaN
# 169136                                          NaN
# ...

# %%
lk = un['likes'].tolist()
rt = un['retweets'].tolist()
cm = un['comments'].tolist()

# %%
N = 10
ind = np.arange(N) 
width = 0.25

# %%
fig, ax = plt.subplots(figsize = (8, 8))
bar1 = plt.bar(ind, lk, width, color = 'r')
bar2 = plt.bar(ind+width, rt, width, color='g')
bar3 = plt.bar(ind+width*2, cm, width, color = 'b')
ax.set_xlabel('Protest ranking based on interactions')
ax.set_ylabel('Total interactions')
ax.set_title('Likes Retweets Comments barplot comparison for top 10 conflicts')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(un['date'], un['sum'])
ax.set_xlabel('date')
ax.set_ylabel('Total interactions')
ax.set_title('Peak interaction periods of top 10 conflicts')
plt.show()

# %%
lke = grouped['likes'].tolist()
rte = grouped['retweets'].tolist()
cme = grouped['comments'].tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-fdc3457b15f4> in <cell line: 1>()
# ----> 1 lke = grouped['likes'].tolist()
#       2 rte = grouped['retweets'].tolist()
#       3 cme = grouped['comments'].tolist()
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     985             return self[attr]
#     986
# --> 987         raise AttributeError(
#     988             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'tolist'

# %%
grouped.head(10)
# Out:
#        Unnamed: 0                                 User  \
# 0               0  https://twitter.com/covid19_info_jp
# 1               1   https://twitter.com/Krishna_000000
# 2               2  https://twitter.com/covid19_info_jp
# 3               3  https://twitter.com/covid19_info_jp
# 4               4  https://twitter.com/JinVDefinatelyU
# ...           ...                                  ...
# 170004          8     https://twitter.com/OfficialAj_3
# 170005          9    https://twitter.com/Indian_Bhakts
# 170017          0   https://twitter.com/MorganEscherly
# 170018          1    https://twitter.com/2141Gmatthews
# 170019          2     https://twitter.com/Eddie_000000
#
#                                    hash  \
# 0       ['æ°åã³ã­ã', 'Covid_19']
# 1                                   NaN
# 2       ['æ°åã³ã­ã', 'Covid_19']
# 3       ['æ°åã³ã­ã', 'Covid_19']
# 4                                   NaN
# ...                                 ...
# ...

# %%
print(grouped['likes'].dtype)
print(grouped['retweets'].dtype)
print(grouped['comments'].dtype)
print(grouped['date'].dtype)
# Out:
# sno
# 1       float64
# 2       float64
# 3       float64
# 4       float64
# 5       float64
#          ...
# 8303    float64
# 8304    float64
# 8305    float64
# 8306    float64
# 8307    float64
# Name: likes, Length: 7114, dtype: object
# sno
# 1       float64
# 2       float64
# 3       float64
# 4       float64
# 5       float64
#          ...
# 8303    float64
# 8304    float64
# 8305    float64
# 8306    float64
# 8307    float64
# Name: retweets, Length: 7114, dtype: object
# sno
# 1       float64
# 2       float64
# 3       float64
# 4       float64
# 5       float64
#          ...
# 8303    float64
# 8304    float64
# 8305    float64
# 8306    float64
# 8307    float64
# Name: comments, Length: 7114, dtype: object
# sno
# 1       object
# 2       object
# 3       object
# 4       object
# 5       object
#          ...
# 8303    object
# 8304    object
# 8305    object
# 8306    object
# 8307    object
# Name: date, Length: 7114, dtype: object

# %%
dfop = pd.read_csv("/content/drive/MyDrive/Similarity matrix folders 100/wholedata.csv")

# %%
dfop.head(10)
# Out:
#    Unnamed: 0    0         1         2         3         4         5    6  \
# 0           0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 1           1  0.0  1.000000  0.077681  0.001342  0.054348  0.074919  0.0
# 2           2  0.0  0.077681  1.000000  0.000000  0.065657  0.820946  0.0
# 3           3  0.0  0.001342  0.000000  1.000000  0.005495  0.094891  0.0
# 4           4  0.0  0.054348  0.065657  0.005495  1.000000  0.064838  0.0
# 5           5  0.0  0.074919  0.820946  0.094891  0.064838  1.000000  0.0
# 6           6  0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 7           7  0.0  0.064136  0.052326  0.268041  0.037344  0.136223  0.0
# 8           8  0.0  0.168157  0.079545  0.001626  0.046479  0.079046  0.0
# 9           9  0.0  0.041522  0.071090  0.004717  0.059190  0.072770  0.0
#
#           7         8  ...      8297      8298      8299      8300      8301  \
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Load correlation matrix from file
dfss = pd.read_csv('/content/drive/MyDrive/Similarity matrix folders 100/wholedata.csv', index_col=0)

# Calculate linkage matrix
Z = linkage(dfss, method='ward', metric='euclidean')

# Plot dendrogram
fig, ax = plt.subplots(figsize=(10, 10))
dendrogram(Z, labels=df.index, ax=ax, leaf_rotation=90, leaf_font_size=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-f9258140c649> in <module>
#       9
#      10 # Calculate linkage matrix
# ---> 11 Z = linkage(dfss, method='ward', metric='euclidean')
#      12
#      13 # Plot dendrogram
#
# /usr/local/lib/python3.9/dist-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1063
#    1064     if not np.all(np.isfinite(y)):
# -> 1065         raise ValueError("The condensed distance matrix must contain only "
#    1066                          "finite values.")
#    1067
#
# ValueError: The condensed distance matrix must contain only finite values.
