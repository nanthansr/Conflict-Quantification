# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
# !pip3 install git+https://github.com/tobe93gf/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/tobe93gf/snscrape.git to /tmp/pip-req-build-hg3ro6c0
#   Running command git clone --filter=blob:none --quiet https://github.com/tobe93gf/snscrape.git /tmp/pip-req-build-hg3ro6c0
#   Resolved https://github.com/tobe93gf/snscrape.git to commit 31a674d6c110086322644f2c929a119767f8785b
#   Preparing metadata (setup.py) ... done
# ...

# %%
import os

path = "gdrive/MyDrive/Final_Year_NO_PRO"
#s.mkdir(path)

# %%
data2 = pd.read_csv('/content/11000_keyword_data.csv')

# %%
data2 = data2.drop(['Unnamed: 0',	'0'],axis=1)

# %%
df = pd.read_csv("/content/withoutprotest.csv")

# %%
df.shape
# Out:
# (11279, 32)

# %%
data2 = data2[2000:]

# %%
data2.shape
# Out:
# (11279, 5)

# %%
data2['date'] = list(df['event_date'][:11279])
# Out:
# <ipython-input-12-e81e76af9404>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['date'] = list(df['event_date'][:11279])

# %%
data2.head()
# Out:
#                   1           2        3         4            5       date
# 2000  demonstrators  barricades  clashed  detained  legislators  05-Aug-22
# 2001      militants   crossfire     fire    rebels      kashmir  05-Aug-22
# 2002            bjp         trs  clashed       mlc   karimnagar  05-Aug-22
# 2003      assaulted   jaleshwar    theft    odisha    kalahandi  05-Aug-22
# 2004      assaulted      odisha  injured     theft    kalahandi  05-Aug-22

# %%
data2.to_csv("inp.csv")

# %%
from cmath import nan
import snscrape.modules.twitter as sntwitter
import pandas as pd 
import datetime

# %%
def scrapeq(query,i):
    limit = 100
    count = 0
    tweets = []
    for tweet in sntwitter.TwitterSearchScraper(query).get_items():
        # print(vars())
        # break
        if len(tweets) == 500000 or count== 10:
            break
        else:
            print(tweet)
            tweets.append([i,tweet.date,tweet.user, tweet.hashtags,tweet.content,tweet.likeCount,tweet.retweetCount,tweet.replyCount])
            count+=1
    if count>=100:
      print(i,query)
      df = pd.DataFrame(tweets,columns=['Rownum','Date','User','hash','content','likes','retweets','comments'])
      df.to_csv(str(path)+'/input'+'_row('+str(i)+').csv')

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
data_new = pd.DataFrame()
def scrape12(query,l):
  tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
  print(query)
  for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
      print(tweet)
      if i>500:
          break
      tweets_list1.append([tweet.date,tweet.user, tweet.hashtags,tweet.content,tweet.likeCount,tweet.retweetCount,tweet.replyCount])
      
  data_new = pd.DataFrame(tweets_list1,columns=['Date','User','hash','content','likes','retweets','comments'])
  data_new.to_csv(str(path)+'/input'+'_row('+str(l)+').csv')

# %%
def main():
    data = pd.read_csv("inp.csv")
    data['date'] = pd.to_datetime(data['date'], errors='coerce')
    l = 0
    for i in range(data.shape[0]):
        query = "("+str(data.iloc[i][str(2)])+" OR "+str(data.iloc[i][str(3)])+" OR "+ str(data.iloc[i][str(4)])+" OR "+str(data.iloc[i][str(5)])+")"+" until:"+str(data.iloc[i]['date']+datetime.timedelta(days=20)) +" since:"+str(data.iloc[i]['date']-datetime.timedelta(days=7))
        scrape12(query,i)
    df = pd.DataFrame(tweets,columns=['Date','User','hash','content','likes','retweets','comments'])
    df.to_csv('input_to_pre.csv')
tweets = []
main()
# Out:
# Streaming output truncated to the last 5000 lines.
# https://twitter.com/ShineRadio2019/status/1243916620684296192
# (asha OR coronavirus OR workers OR surveys) until:2020-04-24 00:00:00 since:2020-03-28 00:00:00
# https://twitter.com/TopTwoNewsWords/status/1253198767781826560
# https://twitter.com/TopTwoNewsWords/status/1252836297107894273
# https://twitter.com/natturnerx65/status/1252831091708162048
# https://twitter.com/TopTwoNewsWords/status/1252474935995518981
# https://twitter.com/TimeFor46783806/status/1252441858451496961
# https://twitter.com/TopTwoNewsWords/status/1252112599463886850
# https://twitter.com/asha_000000/status/1252106318485139457
# https://twitter.com/TopTwoNewsWords/status/1251750137606610950
# https://twitter.com/Krishna_000000/status/1251520595713568770
# https://twitter.com/TopTwoNewsWords/status/1251382260785467392
# https://twitter.com/VMMChamberlain/status/1250838925209489409
# https://twitter.com/SelligAudic/status/1250799031787413506
# ...

# %%
data_new
# Out:
# Empty DataFrame
# Columns: []
# Index: []
